# %%
# Old Dijkstra Version 1.0.0

class DijkstraGreedy():
    def __init__(self, input_graph, s):
        self.vertices = s
        self.graph = input_graph

    # Initialize Q Priority Queue
    def initializeQ(self):
        Q = []
        for _ in graph:
            distance = float('inf')
            self.Insert(Q, self.vertices, distance)
        return Q
    
    def Insert(self, Q, v, distance):
        Q.append((v, distance))
    
    def Decrease(self, Q, v, distance):
        for i in range(len(Q)):
            if Q[i][0] == v:
                Q[i] = (v, distance)
                break

    # Delete the minimum priority element
    def DeleteMin(self, Q):
        minValue = float('inf')
        min_index = None
        for i in range(len(Q)):
            if Q[i][1] < minValue:
                minValue = Q[i][1]
                min_index = i
        return Q.pop(min_index)
    
    def displayDijkstraResult(self, parent, ds):
        print("Vertex \tDistance from Source")
        for v in range(len(self.graph)):
            print(self.vertices, "-", self.vertices[v], "\t", ds)
        print("Parent List: ", parent)
        
    def Dijkstra(self):
        # Initialize Q Priority Queue
        Q = self.initializeQ()
        ds = 0
        self.Decrease(Q, self.vertices, ds) # update priority of s with ds
        Vt = [] # Empty set to store vertices that have been visited
        parent = {}

        n = len(self.graph)

        for i in range(n-1) :
            # Delete the minimum priority element
            u, ds = self.DeleteMin(Q)
            Vt.append(u)
            for v in range(n):
                if self.graph[u][v] > 0 and v not in Vt:
                    if ds + self.graph[u][v] < Q[v][1]:
                        ds = ds + self.graph[u][v]
                        self.Decrease(Q, v, ds)
                        parent[v] = u

        self.displayDijkstraResult(parent, ds)

# %%
# Version 1.1.0

class DijkstraGreedy():

    # Transform the input graph into a list of edges
    def __init__(self, input_graph, vertices, start_vertex=0):
        self.vertices = vertices
        self.start_vertex = start_vertex
        self.graph = []
        self.transformGraph(input_graph)

    def addEdge(self, u, v, w):
        self.graph.append([u, v, w])

    def transformGraph(self, input_graph):
        n = len(input_graph)
        for u in range(n):
            for v in range(u+1, n):
                if input_graph[u][v] > 0:
                    self.addEdge(u, v, w=input_graph[u][v])
    
    def minimum(dict):
        min_key = list(dict.keys())[0]
        for i in list(dict.keys())[1:]:
            if dict[i] < dict[min_key]:
                min_key = i
        return(min_key)
        
    def Dijkstra(self):
        # Initialize Q Priority Queue
        Q = {self.vertices : float('inf') for vertex in self.vertices}
        Q[self.start_vertex] = 0

        while len(Q) != 0:
            explore = self.minimum(Q)
            for edge in self.graph:
                if edge[0] == explore:
                    if Q[edge[1]] in Q.keys():
                        check = Q[explore] + edge[2]
                        if check < Q[edge[1]]:
                            Q[edge[1]] = check
                elif edge[1] == explore:
                    if Q[edge[0]] in Q.keys():
                        check = Q[explore] + edge[2]
                        if check < Q[edge[0]]:
                            Q[edge[0]] = check

# %%
# Version 1.1.0

class DijkstraGreedy2():
    def __init__(self, input_graph, vertices, start_vertex=0):
        self.vertices = vertices
        self.graph = []
        self.transformGraph(input_graph)
        print(self.graph)

    def addEdge(self, u, v, w):
        self.graph.append([u, v, w])

    def transformGraph(self, input_graph):
        n = len(input_graph)
        for u in range(n):
            for v in range(u+1, n):
                if input_graph[u][v] > 0:
                    self.addEdge(u, v, w=input_graph[u][v])

    # Initialize Q Priority Queue
    def initializeQ(self):
        Q = []
        for _ in graph:
            distance = float('inf')
            self.Insert(Q, self.vertices, distance)
        return Q
    
    def minimum(dict):
        min_key = list(dict.keys())[0]
        for i in list(dict.keys())[1:]:
            if dict[i] < dict[min_key]:
                min_key = i
        return(min_key)
    
    def displayDijkstraResult(self, parent, ds):
        print("Vertex \tDistance from Source")
        for v in range(len(self.graph)):
            print(self.vertices, "-", self.vertices[v], "\t", ds)
        print("Parent List: ", parent)
        
    def Dijkstra(self):
        # Initialize Q Priority Queue
        Q = self.initializeQ()
        ds = 0
        self.Decrease(Q, self.vertices, ds) # update priority of s with ds
        Vt = [] # Empty set to store vertices that have been visited
        parent = {}

        n = len(self.graph)

        for i in range(n-1) :
            # Delete the minimum priority element
            u, ds = self.DeleteMin(Q)
            Vt.append(u)
            for v in range(n):
                if self.graph[u][v] > 0 and v not in Vt:
                    if ds + self.graph[u][v] < Q[v][1]:
                        ds = ds + self.graph[u][v]
                        self.Decrease(Q, v, ds)
                        parent[v] = u

        self.displayDijkstraResult(parent, ds)

# %%
# Version 1.2.0

class DijkstraGreedy():

    # Transform the input graph into a list of edges
    def __init__(self, input_graph, vertices, start_vertex=0):
        self.vertices = vertices
        self.start_vertex = start_vertex
        self.graph = []
        self.transformGraph(input_graph)

    def addEdge(self, u, v, w):
        self.graph.append([u, v, w])

    def transformGraph(self, input_graph):
        n = len(input_graph)
        for u in range(n):
            for v in range(u+1, n):
                if input_graph[u][v] > 0:
                    self.addEdge(u, v, w=input_graph[u][v])
    
    def minimum(dict):
        min_key = list(dict.keys())[0]
        for i in list(dict.keys())[1:]:
            if dict[i] < dict[min_key]:
                min_key = i
        return(min_key)
        
    def Dijkstra(self):
        # Initialize Q Priority Queue
        Q = {self.vertices : float('inf') for vertex in self.vertices}
        Q[self.start_vertex] = 0

        while len(Q) != 0:
            explore = self.minimum(Q)
            for edge in self.graph:
                if edge[0] == explore:
                    if Q[edge[1]] in Q.keys():
                        check = Q[explore] + edge[2]
                        if check < Q[edge[1]]:
                            Q[edge[1]] = check
                elif edge[1] == explore:
                    if Q[edge[0]] in Q.keys():
                        check = Q[explore] + edge[2]
                        if check < Q[edge[0]]:
                            Q[edge[0]] = check
