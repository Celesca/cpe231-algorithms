# %% [markdown]
# ### Experimental 1 - Recursive and non-recursive algorithm for computing n!

# %%
import time
import sys

# 👇️ set recursion limit to 2000
sys.setrecursionlimit(10000)

# Recursive Factorial

def recursive_factorial(n):
    if n == 0:
        return 1
    else:
        return n * recursive_factorial(n - 1)
    
batch_epoch = [1000,2000,3000,4000,5000]
re_factorial_time_list = []

for number in batch_epoch:

    start = time.time()

    result = recursive_factorial(number)

    end = time.time()

    re_factorial_time_list.append(end-start)

    print("Time of recursive_factorial :" , end-start , "s")

print(re_factorial_time_list)
# Out:
# Time of recursive_factorial : 0.0009887218475341797 s
# Time of recursive_factorial : 0.0015676021575927734 s
# Time of recursive_factorial : 0.0020766258239746094 s
# Time of recursive_factorial : 0.003995418548583984 s
# Time of recursive_factorial : 0.005999326705932617 s
# [0.0009887218475341797, 0.0015676021575927734, 0.0020766258239746094, 0.003995418548583984, 0.005999326705932617]

# %%
# Non-Recursive Factorial

def nonRecursive_factorial(n):
    if n == 0:
        return 1
    else:
        result = 1
        for i in range(1, n + 1):
            result *= i
        return result
    
batch_epoch = 
nonRe_factorial_time_list = []
    
for number in batch_epoch:

    start = time.time()

    result = nonRecursive_factorial(number)

    end = time.time()

    nonRe_factorial_time_list.append(end-start)

    print("Time of Non-Recursive_factorial :" , end-start , "s")

print(nonRe_factorial_time_list)
# Out:
# Time of Non-Recursive_factorial : 0.0 s
# Time of Non-Recursive_factorial : 0.0009942054748535156 s
# Time of Non-Recursive_factorial : 0.0030024051666259766 s
# Time of Non-Recursive_factorial : 0.0029976367950439453 s
# Time of Non-Recursive_factorial : 0.00499725341796875 s
# [0.0, 0.0009942054748535156, 0.0030024051666259766, 0.0029976367950439453, 0.00499725341796875]

# %%
import matplotlib.pyplot as plt

plt.plot(batch_epoch,re_factorial_time_list )
plt.plot( batch_epoch, nonRe_factorial_time_list)
